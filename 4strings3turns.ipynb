# %%
import random

def pick_two_ends(ends):
    end1, end2 = random.sample(ends, 2)
    ends.remove(end1)
    ends.remove(end2)
    return end1, end2

def replace_ends(ends, end1, end2, turn, loop_count):
    if end1[0] == end2[0]:  # Check if ends have the same number
        print("Loop formed with ends:", end1, "and", end2)
        loop_count[turn] += 1
    else:
        corresponding_end1 = (end1[0], 'B' if end1[1] == 'A' else 'A')
        corresponding_end2 = (end2[0], 'B' if end2[1] == 'A' else 'A')
        if corresponding_end1 in ends:
            ends.remove(corresponding_end1)
        if corresponding_end2 in ends:
            ends.remove(corresponding_end2)
        if turn == 1:
            ends.append((4, 'A'))  # New end
            ends.append((4, 'B'))  # New end
            print("No loop formed. New ends added (turn 1):", (4, 'A'), "and", (4, 'B'))
        elif turn == 2:
            ends.append((5, 'A'))  # New end
            ends.append((5, 'B'))  # New end
            print("No loop formed. New ends added (turn 2):", (5, 'A'), "and", (5, 'B'))
        elif turn == 3:
            ends.append((6, 'A'))  # New end
            ends.append((6, 'B'))  # New end
            print("No loop formed. New ends added (turn 3):", (6, 'A'), "and", (6, 'B'))

def simulate():
    # First turn
    ends = [(n, 'A') for n in range(4)] + [(n, 'B') for n in range(4)]
    print("Initial list of ends:", ends)
    loop_count = {1: 0, 2: 0, 3: 0}
    
    end1, end2 = pick_two_ends(ends)
    print("Picked ends (First turn):", end1, "and", end2)
    
    replace_ends(ends, end1, end2, 1, loop_count)
    
    print("Final list of ends (First turn):", ends)

    # Second turn
    end1, end2 = pick_two_ends(ends)
    print("\nPicked ends (Second turn):", end1, "and", end2)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 2, loop_count)
    
    print("Final list of ends (Second turn):", ends)

    # Third turn
    end1, end2 = pick_two_ends(ends)
    print("\nPicked ends (Third turn):", end1, "and", end2)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 3, loop_count)
    
    print("Final list of ends (Third turn):", ends)
    print("\nTotal loops formed in each turn:", loop_count)
    print("Total number of loops produced:", sum(loop_count.values()))

simulate()
# Out:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (3, 'A') and (2, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(0, 'A'), (1, 'A'), (0, 'B'), (1, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (1, 'B') and (1, 'A')
# Loop formed with ends: (1, 'B') and (1, 'A')
# Final list of ends (Second turn): [(0, 'A'), (0, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Third turn): (4, 'A') and (4, 'B')
# Loop formed with ends: (4, 'A') and (4, 'B')
# Final list of ends (Third turn): [(0, 'A'), (0, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 1, 3: 1}
# Total number of loops produced: 2

# %%
import random

def pick_two_ends(ends):
    end1, end2 = random.sample(ends, 2)
    ends.remove(end1)
    ends.remove(end2)
    return end1, end2

def replace_ends(ends, end1, end2, turn, loop_count):
    if end1[0] == end2[0]:  # Check if ends have the same number
        loop_count[turn] += 1
        print("Loop formed with ends:", end1, "and", end2)
    else:
        corresponding_end1 = (end1[0], 'B' if end1[1] == 'A' else 'A')
        corresponding_end2 = (end2[0], 'B' if end2[1] == 'A' else 'A')
        if corresponding_end1 in ends:
            ends.remove(corresponding_end1)
        if corresponding_end2 in ends:
            ends.remove(corresponding_end2)
        if turn == 1:
            ends.append((4, 'A'))  # New end
            ends.append((4, 'B'))  # New end
            print("No loop formed. New ends added (turn 1):", (4, 'A'), "and", (4, 'B'))
        elif turn == 2:
            ends.append((5, 'A'))  # New end
            ends.append((5, 'B'))  # New end
            print("No loop formed. New ends added (turn 2):", (5, 'A'), "and", (5, 'B'))
        elif turn == 3:
            ends.append((6, 'A'))  # New end
            ends.append((6, 'B'))  # New end
            print("No loop formed. New ends added (turn 3):", (6, 'A'), "and", (6, 'B'))

def simulate():
    # First turn
    ends = [(n, 'A') for n in range(4)] + [(n, 'B') for n in range(4)]
    print("Initial list of ends:", ends)
    loop_count = {1: 0, 2: 0, 3: 0}
    
    end1, end2 = pick_two_ends(ends)
    print("Picked ends (First turn):", end1, "and", end2)
    
    replace_ends(ends, end1, end2, 1, loop_count)
    
    print("Final list of ends (First turn):", ends)

    # Second turn
    end1, end2 = pick_two_ends(ends)
    print("\nPicked ends (Second turn):", end1, "and", end2)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 2, loop_count)
    
    print("Final list of ends (Second turn):", ends)

    # Third turn
    end1, end2 = pick_two_ends(ends)
    print("\nPicked ends (Third turn):", end1, "and", end2)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 3, loop_count)
    
    print("Final list of ends (Third turn):", ends)

 

    print("\nTotal loops formed in each turn:", loop_count)
    print("Total number of loops produced:", sum(loop_count.values()))
    print("-" * 50)

def run_multiple_simulations(num_simulations):
    for i in range(num_simulations):
        print(f"Simulation {i + 1}:")
        simulate()

run_multiple_simulations(10)
# Out:
# Simulation 1:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (3, 'A') and (2, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(0, 'A'), (1, 'A'), (0, 'B'), (1, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (1, 'A') and (0, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(4, 'A'), (4, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'A') and (4, 'B')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 2:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (2, 'B') and (0, 'B')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(1, 'A'), (3, 'A'), (1, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (1, 'B') and (3, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(4, 'A'), (4, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'A') and (5, 'B')
# Loop formed with ends: (5, 'A') and (5, 'B')
# Final list of ends (Third turn): [(4, 'A'), (4, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 1}
# Total number of loops produced: 1
# --------------------------------------------------
# Simulation 3:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (0, 'B') and (2, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(1, 'A'), (3, 'A'), (1, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (3, 'A') and (1, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(4, 'A'), (4, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'A') and (4, 'A')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 4:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (0, 'B') and (1, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(2, 'A'), (3, 'A'), (2, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (4, 'A') and (3, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(2, 'A'), (2, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (2, 'B') and (5, 'B')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 5:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (3, 'B') and (3, 'A')
# Loop formed with ends: (3, 'B') and (3, 'A')
# Final list of ends (First turn): [(0, 'A'), (1, 'A'), (2, 'A'), (0, 'B'), (1, 'B'), (2, 'B')]
#
# Picked ends (Second turn): (2, 'A') and (0, 'A')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(1, 'A'), (1, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (1, 'A') and (5, 'B')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 1, 2: 0, 3: 0}
# Total number of loops produced: 1
# --------------------------------------------------
# Simulation 6:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (0, 'A') and (2, 'B')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(1, 'A'), (3, 'A'), (1, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (3, 'A') and (4, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(1, 'A'), (1, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'B') and (1, 'A')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 7:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (2, 'A') and (1, 'B')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(0, 'A'), (3, 'A'), (0, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (4, 'B') and (3, 'A')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(0, 'A'), (0, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (0, 'A') and (5, 'B')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 8:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (0, 'A') and (2, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(1, 'A'), (3, 'A'), (1, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (4, 'A') and (1, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(3, 'A'), (3, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (3, 'A') and (3, 'B')
# Loop formed with ends: (3, 'A') and (3, 'B')
# Final list of ends (Third turn): [(5, 'A'), (5, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 1}
# Total number of loops produced: 1
# --------------------------------------------------
# Simulation 9:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (2, 'A') and (0, 'B')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(1, 'A'), (3, 'A'), (1, 'B'), (3, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (4, 'A') and (1, 'B')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(3, 'A'), (3, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'B') and (3, 'A')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------
# Simulation 10:
# Initial list of ends: [(0, 'A'), (1, 'A'), (2, 'A'), (3, 'A'), (0, 'B'), (1, 'B'), (2, 'B'), (3, 'B')]
# Picked ends (First turn): (3, 'A') and (2, 'A')
# No loop formed. New ends added (turn 1): (4, 'A') and (4, 'B')
# Final list of ends (First turn): [(0, 'A'), (1, 'A'), (0, 'B'), (1, 'B'), (4, 'A'), (4, 'B')]
#
# Picked ends (Second turn): (0, 'A') and (4, 'A')
# No loop formed. New ends added (turn 2): (5, 'A') and (5, 'B')
# Final list of ends (Second turn): [(1, 'A'), (1, 'B'), (5, 'A'), (5, 'B')]
#
# Picked ends (Third turn): (5, 'A') and (1, 'B')
# No loop formed. New ends added (turn 3): (6, 'A') and (6, 'B')
# Final list of ends (Third turn): [(6, 'A'), (6, 'B')]
#
# Total loops formed in each turn: {1: 0, 2: 0, 3: 0}
# Total number of loops produced: 0
# --------------------------------------------------

# %%
import random

def pick_two_ends(ends):
    end1, end2 = random.sample(ends, 2)
    ends.remove(end1)
    ends.remove(end2)
    return end1, end2

def replace_ends(ends, end1, end2, turn, loop_count):
    if end1[0] == end2[0]:  # Check if ends have the same number
        loop_count[turn] += 1
    else:
        corresponding_end1 = (end1[0], 'B' if end1[1] == 'A' else 'A')
        corresponding_end2 = (end2[0], 'B' if end2[1] == 'A' else 'A')
        if corresponding_end1 in ends:
            ends.remove(corresponding_end1)
        if corresponding_end2 in ends:
            ends.remove(corresponding_end2)
        if turn == 1:
            ends.append((4, 'A'))  # New end
            ends.append((4, 'B'))  # New end
        elif turn == 2:
            ends.append((5, 'A'))  # New end
            ends.append((5, 'B'))  # New end
        elif turn == 3:
            ends.append((6, 'A'))  # New end
            ends.append((6, 'B'))  # New end

def simulate():
    # First turn
    ends = [(n, 'A') for n in range(4)] + [(n, 'B') for n in range(4)]
    loop_count = {1: 0, 2: 0, 3: 0}
    
    end1, end2 = pick_two_ends(ends)
    replace_ends(ends, end1, end2, 1, loop_count)

    # Second turn
    end1, end2 = pick_two_ends(ends)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 2, loop_count)

    # Third turn
    end1, end2 = pick_two_ends(ends)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 3, loop_count)

    return sum(loop_count.values())

def run_multiple_simulations(num_simulations):
    for i in range(num_simulations):
        total_loops = simulate()
        print(f"Simulation {i + 1}: Total number of loops produced: {total_loops}")

run_multiple_simulations(15)
# Out:
# Simulation 1: Total number of loops produced: 0
# Simulation 2: Total number of loops produced: 0
# Simulation 3: Total number of loops produced: 0
# Simulation 4: Total number of loops produced: 2
# Simulation 5: Total number of loops produced: 1
# Simulation 6: Total number of loops produced: 1
# Simulation 7: Total number of loops produced: 1
# Simulation 8: Total number of loops produced: 0
# Simulation 9: Total number of loops produced: 1
# Simulation 10: Total number of loops produced: 1
# Simulation 11: Total number of loops produced: 1
# Simulation 12: Total number of loops produced: 2
# Simulation 13: Total number of loops produced: 1
# Simulation 14: Total number of loops produced: 0
# Simulation 15: Total number of loops produced: 1

# %%
import random

def pick_two_ends(ends):
    end1, end2 = random.sample(ends, 2)
    ends.remove(end1)
    ends.remove(end2)
    return end1, end2

def replace_ends(ends, end1, end2, turn, loop_count):
    if end1[0] == end2[0]:  # Check if ends have the same number
        loop_count[turn] += 1
    else:
        corresponding_end1 = (end1[0], 'B' if end1[1] == 'A' else 'A')
        corresponding_end2 = (end2[0], 'B' if end2[1] == 'A' else 'A')
        if corresponding_end1 in ends:
            ends.remove(corresponding_end1)
        if corresponding_end2 in ends:
            ends.remove(corresponding_end2)
        if turn == 1:
            ends.append((4, 'A'))  # New end
            ends.append((4, 'B'))  # New end
        elif turn == 2:
            ends.append((5, 'A'))  # New end
            ends.append((5, 'B'))  # New end
        elif turn == 3:
            ends.append((6, 'A'))  # New end
            ends.append((6, 'B'))  # New end

def simulate():
    # First turn
    ends = [(n, 'A') for n in range(4)] + [(n, 'B') for n in range(4)]
    loop_count = {1: 0, 2: 0, 3: 0}
    
    end1, end2 = pick_two_ends(ends)
    replace_ends(ends, end1, end2, 1, loop_count)

    # Second turn
    end1, end2 = pick_two_ends(ends)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 2, loop_count)

    # Third turn
    end1, end2 = pick_two_ends(ends)
    if end1 in ends:
        ends.remove(end1)
    if end2 in ends:
        ends.remove(end2)
    replace_ends(ends, end1, end2, 3, loop_count)

    return sum(loop_count.values()), loop_count

def run_multiple_simulations(num_simulations):
    loop_counts = {0: 0, 1: 0, 2: 0, 3: 0}

    for i in range(num_simulations):
        total_loops, counts = simulate()
        loop_counts[total_loops] += 1

    return loop_counts

num_simulations = 1000000
loop_counts = run_multiple_simulations(num_simulations)
print("Number of simulations producing different numbers of loops:")
for loops, count in loop_counts.items():
    print(f"{loops} loops: {count} simulations")
    
print("\nProbability of producing different numbers of loops:")
for loops, count in loop_counts.items():
    probability = count / num_simulations
    print(f"{loops} loops: {probability:.2f}")
# Out:
# Number of simulations producing different numbers of loops:
# 0 loops: 457195 simulations
# 1 loops: 419240 simulations
# 2 loops: 114256 simulations
# 3 loops: 9309 simulations
#
# Probability of producing different numbers of loops:
# 0 loops: 0.46
# 1 loops: 0.42
# 2 loops: 0.11
# 3 loops: 0.01
